# %%
import pandas as pd
import numpy as np
import string
import re
from sklearn.preprocessing import LabelEncoder
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from google.colab import drive

# %%
from torch.optim import AdamW  # Works for PyTorch >= 1.2.0

# %%
drive.mount('/content/drive')
data_path = '/content/drive/My Drive/restaurants_reviews_dataset'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Preprocesing

# %%
df1 = pd.read_csv(data_path + '/Restaurants_Train_v2.csv')

# %%
df1.head()
# Out:
#      id                                           Sentence Aspect Term  \
# 0  3121               But the staff was so horrible to us.       staff
# 1  2777  To be completely fair, the only redeeming fact...        food
# 2  1634  The food is uniformly exceptional, with a very...        food
# 3  1634  The food is uniformly exceptional, with a very...     kitchen
# 4  1634  The food is uniformly exceptional, with a very...        menu
#
#    polarity  from   to
# 0  negative     8   13
# 1  positive    57   61
# 2  positive     4    8
# 3  positive    55   62
# 4   neutral   141  145

# %%
df2 = pd.read_csv(data_path + '/Laptop_Train_v2.csv')

# %%
df2.head()
# Out:
#      id                                           Sentence     Aspect Term  \
# 0  2339  I charge it at night and skip taking the cord ...            cord
# 1  2339  I charge it at night and skip taking the cord ...    battery life
# 2  1316  The tech guy then said the service center does...  service center
# 3  1316  The tech guy then said the service center does...    "sales" team
# 4  1316  The tech guy then said the service center does...        tech guy
#
#    polarity  from   to
# 0   neutral    41   45
# 1  positive    74   86
# 2  negative    27   41
# 3  negative   109  121
# 4   neutral     4   12

# %%
df = pd.concat([df1, df2])

# %%
df.isna().sum()
# Out:
# id             0
# Sentence       0
# Aspect Term    0
# polarity       0
# from           0
# to             0
# dtype: int64

# %%
df["polarity"].value_counts()
# Out:
# polarity
# positive    3151
# negative    1671
# neutral     1093
# conflict     136
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaning Reviews Text

# %%
def clean_text(text):
  """Clean and preprocess text data
  Parameters:
  -----------
  text : str
  The text to clean

  Returns:
  --------
  str
  Cleaned text
  """

  # Convert to lowercase
  text = text.lower()

  # Handle contractions
  contractions = {
      "isn't": "is not", "aren't": "are not", "wasn't": "was not", "weren't": "were not","haven't": "have not",
      "hasn't": "has not", "hadn't": "had not", "doesn't": "does not", "don't": "do not", "didn't": "did not",
      "won't": "will not", "wouldn't": "would not", "can't": "cannot", "couldn't": "could not", "shouldn't": "should not",
      "mightn't": "might not", "mustn't": "must not", "i'm": "i am", "you're": "you are", "he's": "he is", "she's": "she is",
      "it's": "it is", "we're": "we are", "they're": "they are", "i've": "i have", "you've": "you have", "we've": "we have",
      "they've": "they have", "i'd": "i would", "you'd": "you would", "he'd": "he would", "she'd": "she would", "it'd": "it would",
      "we'd": "we would", "they'd": "they would", "i'll": "i will", "you'll": "you will", "he'll": "he will", "she'll": "she will",
      "it'll": "it will", "we'll": "we will", "they'll": "they will", "didnt": "did not", "dont": "do not", "cant": "cannot", "wont": "will not",
      }

  for contraction, expansion in contractions.items():
    text = text.replace(contraction, expansion)

  # Preserve emotions
  emoticons = {
      ':)': ' HAPPY_FACE ',
      ':(': ' SAD_FACE ',
      ':D': ' LAUGH_FACE ',
      ':/': ' CONFUSED_FACE '
      }
  for emoticon, replacement in emoticons.items():
    text = text.replace(emoticon, replacement)


  # Remove punctuation but preserve sentence structure
  text = re.sub(f'[{re.escape(string.punctuation)}]', ' ', text)

  # Remove extra whitespace
  text = re.sub(r'\s+', ' ', text).strip()

  # Restore emotions
  for placeholder, emoticon in {v: k for k, v in emoticons.items()}.items():
    text = text.replace(placeholder, emoticon)

  return text

# %%
cleaned_df = df.copy()
cleaned_df['Sentence'] = cleaned_df['Sentence'].astype(str).apply(clean_text)

# %%
cleaned_df.head()
# Out:
#      id                                           Sentence Aspect Term  \
# 0  3121                but the staff was so horrible to us       staff
# 1  2777  to be completely fair the only redeeming facto...        food
# 2  1634  the food is uniformly exceptional with a very ...        food
# 3  1634  the food is uniformly exceptional with a very ...     kitchen
# 4  1634  the food is uniformly exceptional with a very ...        menu
#
#    polarity  from   to
# 0  negative     8   13
# 1  positive    57   61
# 2  positive     4    8
# 3  positive    55   62
# 4   neutral   141  145

# %% [markdown]
# ## Encoding Polarity Column

# %%
sentiment_encoder = LabelEncoder()

cleaned_df['polarity'] = sentiment_encoder.fit_transform(cleaned_df['polarity'])

# Print the mapping of labels to numbers
label_mapping = dict(zip(sentiment_encoder.classes_, range(len(sentiment_encoder.classes_))))
print(label_mapping)
# Out:
# {'conflict': 0, 'negative': 1, 'neutral': 2, 'positive': 3}

# %%
cleaned_df.head()
# Out:
#      id                                           Sentence Aspect Term  \
# 0  3121                but the staff was so horrible to us       staff
# 1  2777  to be completely fair the only redeeming facto...        food
# 2  1634  the food is uniformly exceptional with a very ...        food
# 3  1634  the food is uniformly exceptional with a very ...     kitchen
# 4  1634  the food is uniformly exceptional with a very ...        menu
#
#    polarity  from   to
# 0         1     8   13
# 1         3    57   61
# 2         3     4    8
# 3         3    55   62
# 4         2   141  145

# %%
cleaned_df['polarity'].dtype
# Out:
# dtype('int64')

# %%
cleaned_df = cleaned_df.drop(['id', 'from', 'to'], axis=1)

# %%
cleaned_df.head()
# Out:
#                                             Sentence Aspect Term  polarity
# 0                but the staff was so horrible to us       staff         1
# 1  to be completely fair the only redeeming facto...        food         3
# 2  the food is uniformly exceptional with a very ...        food         3
# 3  the food is uniformly exceptional with a very ...     kitchen         3
# 4  the food is uniformly exceptional with a very ...        menu         2

# %% [markdown]
# # DistilBERT Fine-tuning

# %%
# Tokenizer setup
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %% [markdown]
# ## Dataset Setup

# %%
class AspectSentimentDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len=128):
        self.data = dataframe.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        review = str(self.data.loc[idx, "text"])
        aspect = str(self.data.loc[idx, "aspect"])
        label = int(self.data.loc[idx, "label"])

        encoded = self.tokenizer(
            review,
            aspect,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt"
        )

        item = {
            "input_ids": encoded["input_ids"].squeeze(0),
            "attention_mask": encoded["attention_mask"].squeeze(0),
            "label": torch.tensor(label, dtype=torch.long)
        }

        return item

# %%
train_df, temp_df = train_test_split(cleaned_df, test_size=0.3, random_state=42)

val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Verify sizes
print(f"Train: {len(train_df)} samples ({len(train_df)/len(cleaned_df)*100:.1f}%)")
print(f"Val: {len(val_df)} samples ({len(val_df)/len(cleaned_df)*100:.1f}%)")
print(f"Test: {len(test_df)} samples ({len(test_df)/len(cleaned_df)*100:.1f}%)")

# Create datasets
train_dataset = AspectDataset(train_df['Sentence'].values, train_df['Aspect Term'].values, train_df['polarity'].values)
val_dataset = AspectDataset(val_df['Sentence'].values, val_df['Aspect Term'].values, val_df['polarity'].values)
test_dataset = AspectDataset(test_df['Sentence'].values, test_df['Aspect Term'].values, test_df['polarity'].values)
# Out:
# Train: 4235 samples (70.0%)
# Val: 908 samples (15.0%)
# Test: 908 samples (15.0%)

# %% [markdown]
# ## Model 1

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# Intermediate layers usually hurt the performance when the dataset is small

# %%
# Model Architecture
class AspectSentimentClassifier(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = torch.nn.Dropout(0.2)

        # Enhanced classifier with intermediate layers
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(768 * 2, 512),  # Intermediate layer 1
            torch.nn.ReLU(),
            torch.nn.LayerNorm(512),
            torch.nn.Linear(512, 128),      # Intermediate layer 2
            torch.nn.GELU(),
            torch.nn.Linear(128, 4)         # Final output (4 classes)
        )

    def forward(self, sentence_input_ids, sentence_attention_mask, aspect_input_ids, aspect_attention_mask):
        # Get sentence embeddings
        sentence_outputs = self.bert(
            input_ids=sentence_input_ids,
            attention_mask=sentence_attention_mask
        )
        sentence_embedding = sentence_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Get aspect embeddings
        aspect_outputs = self.bert(
            input_ids=aspect_input_ids,
            attention_mask=aspect_attention_mask
        )
        aspect_embedding = aspect_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Combine features
        combined = torch.cat([sentence_embedding, aspect_embedding], dim=1)
        combined = self.dropout(combined)
        logits = self.classifier(combined)

        return logits

# %% [markdown]
# ### Training

# %%
# Training Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = AspectSentimentClassifier().to(device)
optimizer = AdamW(model.parameters(), lr=2e-5)
criterion = torch.nn.CrossEntropyLoss()

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

# %%
# Training Loop
def train_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0

    for batch in dataloader:
        optimizer.zero_grad()

        inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
        labels = batch['labels'].to(device)

        outputs = model(**inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

def evaluate(model, dataloader, criterion, debug=False):
    model.eval()
    total_loss = 0.0
    predictions, true_labels = [], []
    class_losses = [0.0] * 4
    class_counts = [0] * 4

    with torch.no_grad():
        for batch_idx, batch in enumerate(dataloader):
            inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(device)

            # Forward pass
            logits = model(**inputs)
            loss = criterion(logits, labels)
            total_loss += loss.item()

            # Per-class loss calculation
            for class_idx in range(4):
                mask = (labels == class_idx)
                if mask.any():
                    class_loss = criterion(logits[mask], labels[mask]).item()
                    class_losses[class_idx] += class_loss * mask.sum().item()
                    class_counts[class_idx] += mask.sum().item()

                    if debug:
                        print(f"Batch {batch_idx} Class {class_idx} Loss: {class_loss:.4f} (n={mask.sum().item()})")

            # Store predictions
            _, preds = torch.max(logits, dim=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    avg_loss = total_loss / len(dataloader)
    class_avg_losses = [
        class_losses[i] / class_counts[i] if class_counts[i] > 0 else 0.0
        for i in range(4)
    ]

    return {
        'loss': avg_loss,
        'class_losses': class_avg_losses,
        'class_counts': class_counts,
        'accuracy': accuracy_score(true_labels, predictions),
        'f1': f1_score(true_labels, predictions, average='macro')
    }

# %%
best_val_loss = float('inf')

# Training Loop
for epoch in range(10):
    model.train()
    train_loss = train_epoch(model, train_loader, optimizer, criterion)

    model.eval()
    val_results = evaluate(model, val_loader, criterion, debug=(epoch == 0))

    # Improved printing
    print(f"\nEpoch {epoch + 1}")
    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss: {val_results['loss']:.4f}")
    print(f"Val Accuracy: {val_results['accuracy']:.4f}")
    print(f"Val F1: {val_results['f1']:.4f}")

    # Class-wise performance
    class_names = ['conflict', 'negative', 'neutral', 'positive']
    print("\nClass-wise Val Loss:")
    for i, name in enumerate(class_names):
        if val_results['class_counts'][i] > 0:
            print(f"{name.upper():<9}: {val_results['class_losses'][i]:.4f} (n={val_results['class_counts'][i]})")
    print("-----")

    # Save the best model based on validation loss (lower is better)
    if val_results['loss'] < best_val_loss:
        best_val_loss = val_results['loss']
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': train_loss,
            'val_loss': val_results['loss'],
            'val_accuracy': val_results['accuracy'],
        }, 'best_model1.pth')
        print(f"Saved new best model with val loss: {best_val_loss:.4f}")
# Out:
# Batch 0 Class 1 Loss: 0.1871 (n=4)
# Batch 0 Class 2 Loss: 0.9432 (n=6)
# Batch 0 Class 3 Loss: 0.2388 (n=6)
# Batch 1 Class 1 Loss: 0.2106 (n=4)
# Batch 1 Class 2 Loss: 1.0955 (n=3)
# Batch 1 Class 3 Loss: 0.4396 (n=9)
# Batch 2 Class 0 Loss: 2.9389 (n=1)
# Batch 2 Class 1 Loss: 1.6393 (n=3)
# Batch 2 Class 2 Loss: 1.6065 (n=1)
# Batch 2 Class 3 Loss: 0.2214 (n=11)
# Batch 3 Class 1 Loss: 0.3251 (n=5)
# Batch 3 Class 2 Loss: 0.5917 (n=3)
# Batch 3 Class 3 Loss: 0.0953 (n=8)
# Batch 4 Class 1 Loss: 0.6239 (n=6)
# Batch 4 Class 2 Loss: 1.5471 (n=1)
# Batch 4 Class 3 Loss: 0.1291 (n=9)
# Batch 5 Class 0 Loss: 4.5115 (n=1)
# Batch 5 Class 1 Loss: 1.3750 (n=3)
# Batch 5 Class 2 Loss: 0.7307 (n=3)
# Batch 5 Class 3 Loss: 0.6351 (n=9)
# Batch 6 Class 1 Loss: 0.3345 (n=4)
# Batch 6 Class 2 Loss: 1.2027 (n=5)
# Batch 6 Class 3 Loss: 0.3911 (n=7)
# Batch 7 Class 1 Loss: 0.4467 (n=7)
# Batch 7 Class 2 Loss: 1.1013 (n=2)
# Batch 7 Class 3 Loss: 0.5750 (n=7)
# Batch 8 Class 1 Loss: 0.3403 (n=3)
# Batch 8 Class 2 Loss: 1.4254 (n=4)
# Batch 8 Class 3 Loss: 0.1230 (n=9)
# Batch 9 Class 0 Loss: 3.4244 (n=1)
# Batch 9 Class 1 Loss: 0.4848 (n=6)
# Batch 9 Class 2 Loss: 1.3123 (n=3)
# Batch 9 Class 3 Loss: 0.3962 (n=6)
# Batch 10 Class 0 Loss: 3.1805 (n=1)
# Batch 10 Class 1 Loss: 0.5479 (n=6)
# Batch 10 Class 2 Loss: 1.9997 (n=3)
# Batch 10 Class 3 Loss: 0.8416 (n=6)
# Batch 11 Class 1 Loss: 0.9015 (n=3)
# Batch 11 Class 2 Loss: 1.6145 (n=6)
# Batch 11 Class 3 Loss: 0.1867 (n=7)
# Batch 12 Class 1 Loss: 0.1493 (n=3)
# Batch 12 Class 2 Loss: 1.2396 (n=5)
# Batch 12 Class 3 Loss: 0.3457 (n=8)
# Batch 13 Class 1 Loss: 0.9753 (n=2)
# Batch 13 Class 2 Loss: 1.7053 (n=4)
# Batch 13 Class 3 Loss: 0.1229 (n=10)
# Batch 14 Class 1 Loss: 1.0194 (n=6)
# Batch 14 Class 2 Loss: 2.4925 (n=1)
# Batch 14 Class 3 Loss: 0.2386 (n=9)
# Batch 15 Class 0 Loss: 2.7975 (n=1)
# Batch 15 Class 1 Loss: 0.6719 (n=2)
# Batch 15 Class 2 Loss: 0.9483 (n=4)
# Batch 15 Class 3 Loss: 0.3375 (n=9)
# Batch 16 Class 1 Loss: 0.2092 (n=2)
# Batch 16 Class 2 Loss: 0.7529 (n=4)
# Batch 16 Class 3 Loss: 0.5019 (n=10)
# Batch 17 Class 0 Loss: 3.2291 (n=1)
# Batch 17 Class 1 Loss: 0.9480 (n=4)
# Batch 17 Class 2 Loss: 1.3828 (n=5)
# Batch 17 Class 3 Loss: 0.0873 (n=6)
# Batch 18 Class 1 Loss: 0.5720 (n=4)
# Batch 18 Class 2 Loss: 1.4109 (n=5)
# Batch 18 Class 3 Loss: 0.0559 (n=7)
# Batch 19 Class 1 Loss: 0.5722 (n=4)
# Batch 19 Class 2 Loss: 1.5314 (n=2)
# Batch 19 Class 3 Loss: 0.0643 (n=10)
# Batch 20 Class 1 Loss: 1.3674 (n=3)
# Batch 20 Class 2 Loss: 1.0425 (n=1)
# Batch 20 Class 3 Loss: 0.1231 (n=12)
# Batch 21 Class 1 Loss: 0.7400 (n=10)
# Batch 21 Class 2 Loss: 0.4455 (n=1)
# Batch 21 Class 3 Loss: 0.1695 (n=5)
# Batch 22 Class 1 Loss: 1.0491 (n=5)
# Batch 22 Class 2 Loss: 1.5328 (n=3)
# Batch 22 Class 3 Loss: 0.2259 (n=8)
# Batch 23 Class 0 Loss: 3.2541 (n=1)
# Batch 23 Class 1 Loss: 0.2605 (n=6)
# Batch 23 Class 2 Loss: 0.6569 (n=3)
# Batch 23 Class 3 Loss: 0.2131 (n=6)
# Batch 24 Class 1 Loss: 1.3799 (n=7)
# Batch 24 Class 2 Loss: 0.9177 (n=2)
# Batch 24 Class 3 Loss: 0.6321 (n=7)
# Batch 25 Class 1 Loss: 0.2990 (n=8)
# Batch 25 Class 2 Loss: 0.4455 (n=1)
# Batch 25 Class 3 Loss: 0.2721 (n=7)
# Batch 26 Class 1 Loss: 0.5674 (n=3)
# Batch 26 Class 2 Loss: 1.3838 (n=5)
# Batch 26 Class 3 Loss: 0.3254 (n=8)
# Batch 27 Class 0 Loss: 3.1171 (n=1)
# Batch 27 Class 1 Loss: 0.5791 (n=5)
# Batch 27 Class 2 Loss: 0.9692 (n=3)
# Batch 27 Class 3 Loss: 0.3175 (n=7)
# Batch 28 Class 1 Loss: 0.3187 (n=3)
# Batch 28 Class 2 Loss: 1.6586 (n=5)
# Batch 28 Class 3 Loss: 0.1956 (n=8)
# Batch 29 Class 1 Loss: 1.3160 (n=3)
# Batch 29 Class 2 Loss: 1.3450 (n=8)
# Batch 29 Class 3 Loss: 0.2994 (n=5)
# Batch 30 Class 1 Loss: 0.6998 (n=2)
# Batch 30 Class 2 Loss: 2.5515 (n=1)
# Batch 30 Class 3 Loss: 0.1041 (n=13)
# Batch 31 Class 1 Loss: 0.2577 (n=2)
# Batch 31 Class 2 Loss: 4.1519 (n=1)
# Batch 31 Class 3 Loss: 0.4447 (n=13)
# Batch 32 Class 1 Loss: 0.1744 (n=1)
# Batch 32 Class 2 Loss: 0.4687 (n=4)
# Batch 32 Class 3 Loss: 0.3487 (n=11)
# Batch 33 Class 1 Loss: 0.7208 (n=5)
# Batch 33 Class 2 Loss: 0.5354 (n=2)
# Batch 33 Class 3 Loss: 0.3003 (n=9)
# Batch 34 Class 1 Loss: 0.9546 (n=5)
# Batch 34 Class 2 Loss: 1.1402 (n=5)
# Batch 34 Class 3 Loss: 0.1490 (n=6)
# Batch 35 Class 1 Loss: 0.5802 (n=5)
# Batch 35 Class 2 Loss: 0.6844 (n=3)
# Batch 35 Class 3 Loss: 0.4388 (n=8)
# Batch 36 Class 1 Loss: 0.1357 (n=1)
# Batch 36 Class 2 Loss: 1.4730 (n=4)
# Batch 36 Class 3 Loss: 0.2902 (n=11)
# Batch 37 Class 1 Loss: 0.6193 (n=7)
# Batch 37 Class 2 Loss: 0.7213 (n=1)
# Batch 37 Class 3 Loss: 0.3443 (n=8)
# Batch 38 Class 0 Loss: 3.8503 (n=1)
# Batch 38 Class 1 Loss: 0.5091 (n=3)
# Batch 38 Class 2 Loss: 1.6906 (n=4)
# Batch 38 Class 3 Loss: 0.2417 (n=8)
# Batch 39 Class 1 Loss: 0.4938 (n=6)
# Batch 39 Class 2 Loss: 1.2196 (n=1)
# Batch 39 Class 3 Loss: 0.0743 (n=9)
# Batch 40 Class 0 Loss: 2.7013 (n=1)
# Batch 40 Class 1 Loss: 1.5366 (n=5)
# Batch 40 Class 2 Loss: 0.9829 (n=2)
# Batch 40 Class 3 Loss: 0.1374 (n=8)
# Batch 41 Class 1 Loss: 0.9333 (n=4)
# Batch 41 Class 2 Loss: 1.5850 (n=3)
# Batch 41 Class 3 Loss: 0.3431 (n=9)
# Batch 42 Class 1 Loss: 0.8215 (n=5)
# Batch 42 Class 2 Loss: 2.2701 (n=4)
# Batch 42 Class 3 Loss: 0.0814 (n=7)
# Batch 43 Class 1 Loss: 0.1764 (n=3)
# Batch 43 Class 2 Loss: 1.4561 (n=1)
# Batch 43 Class 3 Loss: 0.4847 (n=12)
# Batch 44 Class 1 Loss: 1.1003 (n=8)
# Batch 44 Class 2 Loss: 1.0365 (n=3)
# Batch 44 Class 3 Loss: 0.4945 (n=5)
# Batch 45 Class 0 Loss: 3.2780 (n=2)
# Batch 45 Class 1 Loss: 0.2688 (n=5)
# Batch 45 Class 2 Loss: 2.5011 (n=3)
# Batch 45 Class 3 Loss: 0.1461 (n=6)
# Batch 46 Class 1 Loss: 0.6800 (n=4)
# Batch 46 Class 2 Loss: 1.2977 (n=5)
# Batch 46 Class 3 Loss: 0.4220 (n=7)
# Batch 47 Class 1 Loss: 1.6964 (n=2)
# Batch 47 Class 2 Loss: 1.9859 (n=1)
# Batch 47 Class 3 Loss: 0.5311 (n=13)
# Batch 48 Class 0 Loss: 2.9119 (n=1)
# Batch 48 Class 1 Loss: 0.9274 (n=7)
# Batch 48 Class 3 Loss: 0.3119 (n=8)
# Batch 49 Class 0 Loss: 4.2460 (n=1)
# Batch 49 Class 1 Loss: 0.2358 (n=5)
# Batch 49 Class 2 Loss: 1.9027 (n=2)
# Batch 49 Class 3 Loss: 0.1926 (n=8)
# Batch 50 Class 1 Loss: 0.6500 (n=4)
# Batch 50 Class 2 Loss: 1.6353 (n=2)
# Batch 50 Class 3 Loss: 0.2618 (n=10)
# Batch 51 Class 1 Loss: 0.5940 (n=5)
# Batch 51 Class 2 Loss: 1.4992 (n=6)
# Batch 51 Class 3 Loss: 0.0965 (n=5)
# Batch 52 Class 1 Loss: 2.2196 (n=3)
# Batch 52 Class 2 Loss: 0.5087 (n=4)
# Batch 52 Class 3 Loss: 0.0847 (n=9)
# Batch 53 Class 1 Loss: 0.2634 (n=2)
# Batch 53 Class 2 Loss: 1.4090 (n=3)
# Batch 53 Class 3 Loss: 0.4762 (n=11)
# Batch 54 Class 1 Loss: 0.5238 (n=5)
# Batch 54 Class 2 Loss: 0.7169 (n=2)
# Batch 54 Class 3 Loss: 0.2385 (n=9)
# Batch 55 Class 1 Loss: 2.3205 (n=5)
# Batch 55 Class 2 Loss: 0.4055 (n=3)
# Batch 55 Class 3 Loss: 0.3898 (n=8)
# Batch 56 Class 0 Loss: 2.8837 (n=1)
# Batch 56 Class 1 Loss: 0.5708 (n=2)
# Batch 56 Class 2 Loss: 1.0423 (n=1)
# Batch 56 Class 3 Loss: 0.1420 (n=8)
#
# Epoch 1
# Train Loss: 0.8272
# Val Loss: 0.6480
# Val Accuracy: 0.7621
# Val F1: 0.5290
#
# Class-wise Val Loss:
# CONFLICT : 3.3068 (n=15)
# NEGATIVE : 0.7319 (n=245)
# NEUTRAL  : 1.2864 (n=173)
# POSITIVE : 0.2893 (n=475)
# -----
# Saved new best model with val loss: 0.6480
#
# Epoch 2
# Train Loss: 0.5840
# Val Loss: 0.6287
# Val Accuracy: 0.7533
# Val F1: 0.5256
#
# Class-wise Val Loss:
# CONFLICT : 2.6329 (n=15)
# NEGATIVE : 0.8537 (n=245)
# NEUTRAL  : 1.0421 (n=173)
# POSITIVE : 0.3000 (n=475)
# -----
# Saved new best model with val loss: 0.6287
#
# Epoch 3
# Train Loss: 0.4566
# Val Loss: 0.6601
# Val Accuracy: 0.7610
# Val F1: 0.5491
#
# Class-wise Val Loss:
# CONFLICT : 2.0626 (n=15)
# NEGATIVE : 0.7507 (n=245)
# NEUTRAL  : 1.4007 (n=173)
# POSITIVE : 0.3012 (n=475)
# -----
#
# Epoch 4
# Train Loss: 0.3588
# Val Loss: 0.7276
# Val Accuracy: 0.7588
# Val F1: 0.5702
#
# Class-wise Val Loss:
# CONFLICT : 2.5331 (n=15)
# NEGATIVE : 0.8814 (n=245)
# NEUTRAL  : 1.6487 (n=173)
# POSITIVE : 0.2568 (n=475)
# -----
#
# Epoch 5
# Train Loss: 0.2873
# Val Loss: 0.8107
# Val Accuracy: 0.7555
# Val F1: 0.5697
#
# Class-wise Val Loss:
# CONFLICT : 2.9753 (n=15)
# NEGATIVE : 1.0386 (n=245)
# NEUTRAL  : 1.5605 (n=173)
# POSITIVE : 0.3532 (n=475)
# -----
#
# Epoch 6
# Train Loss: 0.2302
# Val Loss: 0.8523
# Val Accuracy: 0.7522
# Val F1: 0.5686
#
# Class-wise Val Loss:
# CONFLICT : 2.1132 (n=15)
# NEGATIVE : 0.9379 (n=245)
# NEUTRAL  : 2.0348 (n=173)
# POSITIVE : 0.3417 (n=475)
# -----
#
# Epoch 7
# Train Loss: 0.1887
# Val Loss: 0.8970
# Val Accuracy: 0.7500
# Val F1: 0.5803
#
# Class-wise Val Loss:
# CONFLICT : 2.6902 (n=15)
# NEGATIVE : 1.0048 (n=245)
# NEUTRAL  : 1.7662 (n=173)
# POSITIVE : 0.4692 (n=475)
# -----
#
# Epoch 8
# Train Loss: 0.1528
# Val Loss: 1.0045
# Val Accuracy: 0.7368
# Val F1: 0.5705
#
# Class-wise Val Loss:
# CONFLICT : 3.5712 (n=15)
# NEGATIVE : 1.2186 (n=245)
# NEUTRAL  : 1.9856 (n=173)
# POSITIVE : 0.4568 (n=475)
# -----
#
# Epoch 9
# Train Loss: 0.1226
# Val Loss: 1.0020
# Val Accuracy: 0.7280
# Val F1: 0.5801
#
# Class-wise Val Loss:
# CONFLICT : 2.3535 (n=15)
# NEGATIVE : 1.1660 (n=245)
# NEUTRAL  : 1.6199 (n=173)
# POSITIVE : 0.6539 (n=475)
# -----
#
# Epoch 10
# Train Loss: 0.1112
# Val Loss: 1.1271
# Val Accuracy: 0.7434
# Val F1: 0.5767
#
# Class-wise Val Loss:
# CONFLICT : 3.5132 (n=15)
# NEGATIVE : 1.5439 (n=245)
# NEUTRAL  : 2.0003 (n=173)
# POSITIVE : 0.5235 (n=475)
# -----

# %%
"""
best_model = torch.load('best_model1.pth')
model.load_state_dict(best_model['model_state_dict'])"""

checkpoint = torch.load('best_model1.pth')
print(f"Model 1 Best validation loss: {checkpoint['val_loss']:.4f}")
print(f"Achieved at epoch: {checkpoint['epoch'] + 1}")

# Evaluate on the test set ONLY ONCE
model.eval()
test_results = evaluate(model, test_loader, criterion)
print(f"\nModel 1 Final Test Performance:")
print(f"Test Loss: {test_results['loss']:.4f}")
print(f"Test Accuracy: {test_results['accuracy']:.4f}")
print(f"Test F1: {test_results['f1']:.4f}")
# Out:
# Model 1 Best validation loss: 0.6287
# Achieved at epoch: 2
#
# Model 1 Final Test Performance:
# Test Loss: 1.0029
# Test Accuracy: 0.7335
# Test F1: 0.5139

# %%
# save model
torch.save(model.state_dict(), 'model1.pt')

# %% [markdown]
# ## Model 2

# %% [markdown]
# ### Model Architecture

# %%
class AspectSentimentClassifier(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = torch.nn.Dropout(0.2)

        # Enhanced classifier with intermediate layers
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(768 * 2, 512),  # Intermediate layer 1
            torch.nn.ReLU(),
            torch.nn.LayerNorm(512),
            torch.nn.Linear(512, 128),      # Intermediate layer 2
            torch.nn.GELU(),
            torch.nn.Linear(128, 4)         # Final output (4 classes)
        )

    def forward(self, sentence_input_ids, sentence_attention_mask, aspect_input_ids, aspect_attention_mask):
        # Get sentence embeddings
        sentence_outputs = self.bert(
            input_ids=sentence_input_ids,
            attention_mask=sentence_attention_mask
        )
        sentence_embedding = sentence_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Get aspect embeddings
        aspect_outputs = self.bert(
            input_ids=aspect_input_ids,
            attention_mask=aspect_attention_mask
        )
        aspect_embedding = aspect_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Combine features
        combined = torch.cat([sentence_embedding, aspect_embedding], dim=1)
        combined = self.dropout(combined)
        logits = self.classifier(combined)

        return logits

# %%
# Training Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model2 = AspectSentimentClassifier().to(device)
optimizer = AdamW(model2.parameters(), lr=2e-5)

# %%
class_counts = torch.tensor([
    91,    # conflict (class 0)
    805,   # negative (class 1)
    633,   # neutral (class 2)
    2164   # positive (class 3)
])

# Calculate weights (inverse frequency)
weights = 1. / class_counts.float()

# Normalize to sum to num_classes (4)
weights = weights / weights.sum() * len(class_counts)

# Verify weight-class alignment
print({
    'conflict': weights[0].item(),  # Should be LARGEST (~3.75)
    'negative': weights[1].item(),   # ~1.23
    'neutral': weights[2].item(),    # ~1.57
    'positive': weights[3].item()    # Should be SMALLEST (~0.45)
})

# Initialize loss function
criterion = torch.nn.CrossEntropyLoss(weight=weights.to(device))
# Out:
# {'conflict': 3.0796351432800293, 'negative': 0.3481326401233673, 'neutral': 0.4427279531955719, 'positive': 0.12950406968593597}

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

# %% [markdown]
# ### Training

# %%
# Training Loop
def train_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0

    for batch in dataloader:
        optimizer.zero_grad()

        inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
        labels = batch['labels'].to(device)

        outputs = model(**inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate(model, dataloader, criterion, debug=False):
    model.eval()
    total_loss = 0.0
    predictions, true_labels = [], []
    class_losses = [0.0] * 4
    class_counts = [0] * 4

    with torch.no_grad():
        for batch_idx, batch in enumerate(dataloader):
            inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(device)

            # Forward pass
            logits = model(**inputs)
            loss = criterion(logits, labels)
            total_loss += loss.item()

            # Per-class loss calculation
            for class_idx in range(4):
                mask = (labels == class_idx)
                if mask.any():
                    class_loss = criterion(logits[mask], labels[mask]).item()
                    class_losses[class_idx] += class_loss * mask.sum().item()
                    class_counts[class_idx] += mask.sum().item()

                    if debug:
                        print(f"Batch {batch_idx} Class {class_idx} Loss: {class_loss:.4f} (n={mask.sum().item()})")

            # Store predictions
            _, preds = torch.max(logits, dim=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    avg_loss = total_loss / len(dataloader)
    class_avg_losses = [
        class_losses[i] / class_counts[i] if class_counts[i] > 0 else 0.0
        for i in range(4)
    ]

    return {
        'loss': avg_loss,
        'class_losses': class_avg_losses,
        'class_counts': class_counts,
        'accuracy': accuracy_score(true_labels, predictions),
        'f1': f1_score(true_labels, predictions, average='macro')
    }

# %%
best_val_loss = float('inf')  # Initialize with a very high value if tracking loss

# Training Loop
for epoch in range(10):
    model2.train()
    train_loss = train_epoch(model2, train_loader, optimizer, criterion)

    model2.eval()
    val_results = evaluate(model2, val_loader, criterion, debug=(epoch == 0))

    # Improved printing
    print(f"\nEpoch {epoch + 1}")
    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss: {val_results['loss']:.4f}")
    print(f"Val Accuracy: {val_results['accuracy']:.4f}")
    print(f"Val F1: {val_results['f1']:.4f}")

    # Class-wise performance
    class_names = ['conflict', 'negative', 'neutral', 'positive']
    print("\nClass-wise Val Loss:")
    for i, name in enumerate(class_names):
        if val_results['class_counts'][i] > 0:
            print(f"{name.upper():<9}: {val_results['class_losses'][i]:.4f} (n={val_results['class_counts'][i]})")
    print("-----")

    if val_results['loss'] < best_val_loss:
      best_val_loss = val_results['loss']
      torch.save({
          'epoch': epoch,
          'model_state_dict': model.state_dict(),
          'optimizer_state_dict': optimizer.state_dict(),
          'loss': train_loss,
          'val_loss': val_results['loss'],
          'val_accuracy': val_results['accuracy'],
      }, 'best_model2.pth')
      print(f"Saved new best model with val loss: {best_val_loss:.4f}")
# Out:
# Batch 0 Class 1 Loss: 0.2117 (n=4)
# Batch 0 Class 2 Loss: 0.9560 (n=6)
# Batch 0 Class 3 Loss: 0.4766 (n=6)
# Batch 1 Class 1 Loss: 0.3139 (n=4)
# Batch 1 Class 2 Loss: 0.7635 (n=3)
# Batch 1 Class 3 Loss: 0.6628 (n=9)
# Batch 2 Class 0 Loss: 0.7583 (n=1)
# Batch 2 Class 1 Loss: 1.3445 (n=3)
# Batch 2 Class 2 Loss: 1.6220 (n=1)
# Batch 2 Class 3 Loss: 0.4993 (n=11)
# Batch 3 Class 1 Loss: 0.6819 (n=5)
# Batch 3 Class 2 Loss: 0.5073 (n=3)
# Batch 3 Class 3 Loss: 0.2110 (n=8)
# Batch 4 Class 1 Loss: 0.6697 (n=6)
# Batch 4 Class 2 Loss: 1.1741 (n=1)
# Batch 4 Class 3 Loss: 0.2877 (n=9)
# Batch 5 Class 0 Loss: 2.8732 (n=1)
# Batch 5 Class 1 Loss: 1.2577 (n=3)
# Batch 5 Class 2 Loss: 0.7179 (n=3)
# Batch 5 Class 3 Loss: 1.0691 (n=9)
# Batch 6 Class 1 Loss: 0.4813 (n=4)
# Batch 6 Class 2 Loss: 1.0779 (n=5)
# Batch 6 Class 3 Loss: 0.4546 (n=7)
# Batch 7 Class 1 Loss: 0.6018 (n=7)
# Batch 7 Class 2 Loss: 0.5647 (n=2)
# Batch 7 Class 3 Loss: 0.6622 (n=7)
# Batch 8 Class 1 Loss: 0.4119 (n=3)
# Batch 8 Class 2 Loss: 1.0962 (n=4)
# Batch 8 Class 3 Loss: 0.2745 (n=9)
# Batch 9 Class 0 Loss: 1.6943 (n=1)
# Batch 9 Class 1 Loss: 0.9696 (n=6)
# Batch 9 Class 2 Loss: 1.0369 (n=3)
# Batch 9 Class 3 Loss: 0.8504 (n=6)
# Batch 10 Class 0 Loss: 1.0244 (n=1)
# Batch 10 Class 1 Loss: 0.3811 (n=6)
# Batch 10 Class 2 Loss: 1.1244 (n=3)
# Batch 10 Class 3 Loss: 1.1054 (n=6)
# Batch 11 Class 1 Loss: 1.2564 (n=3)
# Batch 11 Class 2 Loss: 1.3681 (n=6)
# Batch 11 Class 3 Loss: 0.5282 (n=7)
# Batch 12 Class 1 Loss: 0.2008 (n=3)
# Batch 12 Class 2 Loss: 1.1483 (n=5)
# Batch 12 Class 3 Loss: 0.8915 (n=8)
# Batch 13 Class 1 Loss: 0.9216 (n=2)
# Batch 13 Class 2 Loss: 1.4407 (n=4)
# Batch 13 Class 3 Loss: 0.2740 (n=10)
# Batch 14 Class 1 Loss: 0.8558 (n=6)
# Batch 14 Class 2 Loss: 1.6103 (n=1)
# Batch 14 Class 3 Loss: 0.7526 (n=9)
# Batch 15 Class 0 Loss: 0.9636 (n=1)
# Batch 15 Class 1 Loss: 0.4596 (n=2)
# Batch 15 Class 2 Loss: 0.8745 (n=4)
# Batch 15 Class 3 Loss: 0.4689 (n=9)
# Batch 16 Class 1 Loss: 0.1838 (n=2)
# Batch 16 Class 2 Loss: 0.5862 (n=4)
# Batch 16 Class 3 Loss: 0.8819 (n=10)
# Batch 17 Class 0 Loss: 2.7207 (n=1)
# Batch 17 Class 1 Loss: 0.6007 (n=4)
# Batch 17 Class 2 Loss: 1.1281 (n=5)
# Batch 17 Class 3 Loss: 0.3951 (n=6)
# Batch 18 Class 1 Loss: 0.4486 (n=4)
# Batch 18 Class 2 Loss: 1.1770 (n=5)
# Batch 18 Class 3 Loss: 0.1476 (n=7)
# Batch 19 Class 1 Loss: 0.5672 (n=4)
# Batch 19 Class 2 Loss: 2.0127 (n=2)
# Batch 19 Class 3 Loss: 0.2157 (n=10)
# Batch 20 Class 1 Loss: 1.1416 (n=3)
# Batch 20 Class 2 Loss: 0.9249 (n=1)
# Batch 20 Class 3 Loss: 0.4511 (n=12)
# Batch 21 Class 1 Loss: 0.8198 (n=10)
# Batch 21 Class 2 Loss: 0.8017 (n=1)
# Batch 21 Class 3 Loss: 0.6073 (n=5)
# Batch 22 Class 1 Loss: 0.8491 (n=5)
# Batch 22 Class 2 Loss: 1.5293 (n=3)
# Batch 22 Class 3 Loss: 0.4249 (n=8)
# Batch 23 Class 0 Loss: 1.4321 (n=1)
# Batch 23 Class 1 Loss: 0.3259 (n=6)
# Batch 23 Class 2 Loss: 0.5774 (n=3)
# Batch 23 Class 3 Loss: 0.4962 (n=6)
# Batch 24 Class 1 Loss: 0.9554 (n=7)
# Batch 24 Class 2 Loss: 0.8911 (n=2)
# Batch 24 Class 3 Loss: 0.5641 (n=7)
# Batch 25 Class 1 Loss: 0.4093 (n=8)
# Batch 25 Class 2 Loss: 0.6012 (n=1)
# Batch 25 Class 3 Loss: 0.5225 (n=7)
# Batch 26 Class 1 Loss: 0.5035 (n=3)
# Batch 26 Class 2 Loss: 1.0141 (n=5)
# Batch 26 Class 3 Loss: 0.8546 (n=8)
# Batch 27 Class 0 Loss: 1.9705 (n=1)
# Batch 27 Class 1 Loss: 0.4662 (n=5)
# Batch 27 Class 2 Loss: 0.8620 (n=3)
# Batch 27 Class 3 Loss: 0.8169 (n=7)
# Batch 28 Class 1 Loss: 0.2810 (n=3)
# Batch 28 Class 2 Loss: 1.3092 (n=5)
# Batch 28 Class 3 Loss: 0.4033 (n=8)
# Batch 29 Class 1 Loss: 1.6691 (n=3)
# Batch 29 Class 2 Loss: 0.8429 (n=8)
# Batch 29 Class 3 Loss: 0.7249 (n=5)
# Batch 30 Class 1 Loss: 0.7946 (n=2)
# Batch 30 Class 2 Loss: 1.6414 (n=1)
# Batch 30 Class 3 Loss: 0.4743 (n=13)
# Batch 31 Class 1 Loss: 0.2491 (n=2)
# Batch 31 Class 2 Loss: 3.3132 (n=1)
# Batch 31 Class 3 Loss: 0.9367 (n=13)
# Batch 32 Class 1 Loss: 0.4713 (n=1)
# Batch 32 Class 2 Loss: 0.5102 (n=4)
# Batch 32 Class 3 Loss: 0.9412 (n=11)
# Batch 33 Class 1 Loss: 0.6290 (n=5)
# Batch 33 Class 2 Loss: 0.5412 (n=2)
# Batch 33 Class 3 Loss: 0.3745 (n=9)
# Batch 34 Class 1 Loss: 0.8948 (n=5)
# Batch 34 Class 2 Loss: 0.9166 (n=5)
# Batch 34 Class 3 Loss: 0.3217 (n=6)
# Batch 35 Class 1 Loss: 0.5562 (n=5)
# Batch 35 Class 2 Loss: 0.7804 (n=3)
# Batch 35 Class 3 Loss: 0.8701 (n=8)
# Batch 36 Class 1 Loss: 0.1889 (n=1)
# Batch 36 Class 2 Loss: 1.5017 (n=4)
# Batch 36 Class 3 Loss: 0.5002 (n=11)
# Batch 37 Class 1 Loss: 0.6610 (n=7)
# Batch 37 Class 2 Loss: 0.5612 (n=1)
# Batch 37 Class 3 Loss: 0.4190 (n=8)
# Batch 38 Class 0 Loss: 1.0892 (n=1)
# Batch 38 Class 1 Loss: 0.5608 (n=3)
# Batch 38 Class 2 Loss: 1.4317 (n=4)
# Batch 38 Class 3 Loss: 0.6096 (n=8)
# Batch 39 Class 1 Loss: 0.3986 (n=6)
# Batch 39 Class 2 Loss: 1.3941 (n=1)
# Batch 39 Class 3 Loss: 0.4198 (n=9)
# Batch 40 Class 0 Loss: 1.5822 (n=1)
# Batch 40 Class 1 Loss: 1.4945 (n=5)
# Batch 40 Class 2 Loss: 0.9898 (n=2)
# Batch 40 Class 3 Loss: 0.6926 (n=8)
# Batch 41 Class 1 Loss: 0.4693 (n=4)
# Batch 41 Class 2 Loss: 1.1294 (n=3)
# Batch 41 Class 3 Loss: 0.3979 (n=9)
# Batch 42 Class 1 Loss: 1.1567 (n=5)
# Batch 42 Class 2 Loss: 1.9278 (n=4)
# Batch 42 Class 3 Loss: 0.2128 (n=7)
# Batch 43 Class 1 Loss: 0.3422 (n=3)
# Batch 43 Class 2 Loss: 1.3696 (n=1)
# Batch 43 Class 3 Loss: 0.7221 (n=12)
# Batch 44 Class 1 Loss: 0.8753 (n=8)
# Batch 44 Class 2 Loss: 0.9748 (n=3)
# Batch 44 Class 3 Loss: 0.6023 (n=5)
# Batch 45 Class 0 Loss: 0.8459 (n=2)
# Batch 45 Class 1 Loss: 0.5061 (n=5)
# Batch 45 Class 2 Loss: 1.8424 (n=3)
# Batch 45 Class 3 Loss: 0.2410 (n=6)
# Batch 46 Class 1 Loss: 0.4802 (n=4)
# Batch 46 Class 2 Loss: 1.0174 (n=5)
# Batch 46 Class 3 Loss: 0.6310 (n=7)
# Batch 47 Class 1 Loss: 1.1794 (n=2)
# Batch 47 Class 2 Loss: 1.8494 (n=1)
# Batch 47 Class 3 Loss: 0.9411 (n=13)
# Batch 48 Class 0 Loss: 0.8759 (n=1)
# Batch 48 Class 1 Loss: 0.8887 (n=7)
# Batch 48 Class 3 Loss: 0.8351 (n=8)
# Batch 49 Class 0 Loss: 2.7459 (n=1)
# Batch 49 Class 1 Loss: 0.2412 (n=5)
# Batch 49 Class 2 Loss: 1.3104 (n=2)
# Batch 49 Class 3 Loss: 0.4053 (n=8)
# Batch 50 Class 1 Loss: 0.5769 (n=4)
# Batch 50 Class 2 Loss: 1.1457 (n=2)
# Batch 50 Class 3 Loss: 0.5719 (n=10)
# Batch 51 Class 1 Loss: 0.6103 (n=5)
# Batch 51 Class 2 Loss: 1.1888 (n=6)
# Batch 51 Class 3 Loss: 0.2403 (n=5)
# Batch 52 Class 1 Loss: 1.7605 (n=3)
# Batch 52 Class 2 Loss: 0.6577 (n=4)
# Batch 52 Class 3 Loss: 0.1877 (n=9)
# Batch 53 Class 1 Loss: 0.2890 (n=2)
# Batch 53 Class 2 Loss: 1.3458 (n=3)
# Batch 53 Class 3 Loss: 0.6949 (n=11)
# Batch 54 Class 1 Loss: 0.7579 (n=5)
# Batch 54 Class 2 Loss: 0.4679 (n=2)
# Batch 54 Class 3 Loss: 0.4376 (n=9)
# Batch 55 Class 1 Loss: 1.5865 (n=5)
# Batch 55 Class 2 Loss: 0.4256 (n=3)
# Batch 55 Class 3 Loss: 0.4982 (n=8)
# Batch 56 Class 0 Loss: 1.1167 (n=1)
# Batch 56 Class 1 Loss: 0.4448 (n=2)
# Batch 56 Class 2 Loss: 0.7886 (n=1)
# Batch 56 Class 3 Loss: 0.4351 (n=8)
#
# Epoch 1
# Train Loss: 1.0998
# Val Loss: 0.8730
# Val Accuracy: 0.7137
# Val F1: 0.5730
#
# Class-wise Val Loss:
# CONFLICT : 1.5026 (n=15)
# NEGATIVE : 0.7040 (n=245)
# NEUTRAL  : 1.0764 (n=173)
# POSITIVE : 0.5631 (n=475)
# -----
# Saved new best model with val loss: 0.8730
#
# Epoch 2
# Train Loss: 0.7933
# Val Loss: 0.7821
# Val Accuracy: 0.6839
# Val F1: 0.5680
#
# Class-wise Val Loss:
# CONFLICT : 0.8542 (n=15)
# NEGATIVE : 0.6442 (n=245)
# NEUTRAL  : 0.7832 (n=173)
# POSITIVE : 0.9259 (n=475)
# -----
# Saved new best model with val loss: 0.7821
#
# Epoch 3
# Train Loss: 0.6187
# Val Loss: 0.8575
# Val Accuracy: 0.6894
# Val F1: 0.5654
#
# Class-wise Val Loss:
# CONFLICT : 1.4335 (n=15)
# NEGATIVE : 0.8185 (n=245)
# NEUTRAL  : 0.6985 (n=173)
# POSITIVE : 0.8288 (n=475)
# -----
#
# Epoch 4
# Train Loss: 0.4817
# Val Loss: 0.8888
# Val Accuracy: 0.6982
# Val F1: 0.5768
#
# Class-wise Val Loss:
# CONFLICT : 1.2148 (n=15)
# NEGATIVE : 0.9250 (n=245)
# NEUTRAL  : 0.8042 (n=173)
# POSITIVE : 0.8147 (n=475)
# -----
#
# Epoch 5
# Train Loss: 0.3828
# Val Loss: 0.9941
# Val Accuracy: 0.7203
# Val F1: 0.5680
#
# Class-wise Val Loss:
# CONFLICT : 1.7571 (n=15)
# NEGATIVE : 0.9442 (n=245)
# NEUTRAL  : 1.1050 (n=173)
# POSITIVE : 0.6231 (n=475)
# -----
#
# Epoch 6
# Train Loss: 0.3002
# Val Loss: 1.1075
# Val Accuracy: 0.7192
# Val F1: 0.5766
#
# Class-wise Val Loss:
# CONFLICT : 1.5879 (n=15)
# NEGATIVE : 0.9145 (n=245)
# NEUTRAL  : 1.5377 (n=173)
# POSITIVE : 0.6607 (n=475)
# -----
#
# Epoch 7
# Train Loss: 0.2623
# Val Loss: 1.2855
# Val Accuracy: 0.7148
# Val F1: 0.5755
#
# Class-wise Val Loss:
# CONFLICT : 2.1295 (n=15)
# NEGATIVE : 1.2821 (n=245)
# NEUTRAL  : 1.5752 (n=173)
# POSITIVE : 0.5772 (n=475)
# -----
#
# Epoch 8
# Train Loss: 0.2234
# Val Loss: 1.3642
# Val Accuracy: 0.7335
# Val F1: 0.5802
#
# Class-wise Val Loss:
# CONFLICT : 2.8684 (n=15)
# NEGATIVE : 1.3608 (n=245)
# NEUTRAL  : 1.4754 (n=173)
# POSITIVE : 0.5450 (n=475)
# -----
#
# Epoch 9
# Train Loss: 0.1812
# Val Loss: 1.4461
# Val Accuracy: 0.7313
# Val F1: 0.5662
#
# Class-wise Val Loss:
# CONFLICT : 3.6173 (n=15)
# NEGATIVE : 1.2714 (n=245)
# NEUTRAL  : 1.4797 (n=173)
# POSITIVE : 0.6819 (n=475)
# -----
#
# Epoch 10
# Train Loss: 0.1636
# Val Loss: 1.4153
# Val Accuracy: 0.7390
# Val F1: 0.5915
#
# Class-wise Val Loss:
# CONFLICT : 3.7869 (n=15)
# NEGATIVE : 1.1181 (n=245)
# NEUTRAL  : 1.4773 (n=173)
# POSITIVE : 0.7178 (n=475)
# -----

# %%
checkpoint = torch.load('best_model2.pth')
print(f"Model 2 Best validation loss: {checkpoint['val_loss']:.4f}")
print(f"Achieved at epoch: {checkpoint['epoch'] + 1}")

# Evaluate on the test set ONLY ONCE
model2.eval()
test_results = evaluate(model2, test_loader, criterion)
print(f"\nModel 2 Final Test Performance:")
print(f"Test Loss: {test_results['loss']:.4f}")
print(f"Test Accuracy: {test_results['accuracy']:.4f}")
print(f"Test F1: {test_results['f1']:.4f}")
# Out:
# Model 2 Best validation loss: 0.7821
# Achieved at epoch: 2
#
# Model 2 Final Test Performance:
# Test Loss: 1.5158
# Test Accuracy: 0.7225
# Test F1: 0.5759

# %% [markdown]
# ## Model 3

# %% [markdown]
# ### Model Architecture

# %%
class AspectSentimentClassifier(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = torch.nn.Dropout(0.5)  # Increased from 0.2
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(768*2, 512),
            torch.nn.ReLU(),
            torch.nn.LayerNorm(512),
            torch.nn.Dropout(0.3),  # Additional dropout
            torch.nn.Linear(512, 128),
            torch.nn.GELU(),
            torch.nn.Dropout(0.3),  # Additional dropout
            torch.nn.Linear(128, 4)
        )

    def forward(self, sentence_input_ids, sentence_attention_mask, aspect_input_ids, aspect_attention_mask):
        # Get sentence embeddings
        sentence_outputs = self.bert(
            input_ids=sentence_input_ids,
            attention_mask=sentence_attention_mask
        )
        sentence_embedding = sentence_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Get aspect embeddings
        aspect_outputs = self.bert(
            input_ids=aspect_input_ids,
            attention_mask=aspect_attention_mask
        )
        aspect_embedding = aspect_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Combine features
        combined = torch.cat([sentence_embedding, aspect_embedding], dim=1)
        combined = self.dropout(combined)
        logits = self.classifier(combined)

        return logits

# %%
# Training Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model3 = AspectSentimentClassifier().to(device)
optimizer = AdamW(model3.parameters(), lr=2e-5)

# %%
class_counts = torch.tensor([
    91,    # conflict (class 0)
    805,   # negative (class 1)
    633,   # neutral (class 2)
    2164   # positive (class 3)
])

# Calculate weights (inverse frequency)
weights = 1. / class_counts.float()

# Normalize to sum to num_classes (4)
weights = weights / weights.sum() * len(class_counts)

# Verify weight-class alignment
print({
    'conflict': weights[0].item(),  # Should be LARGEST (~3.75)
    'negative': weights[1].item(),   # ~1.23
    'neutral': weights[2].item(),    # ~1.57
    'positive': weights[3].item()    # Should be SMALLEST (~0.45)
})

# Initialize loss function
criterion = torch.nn.CrossEntropyLoss(weight=weights.to(device))
# Out:
# {'conflict': 3.0796351432800293, 'negative': 0.3481326401233673, 'neutral': 0.4427279531955719, 'positive': 0.12950406968593597}

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

# %% [markdown]
# ### Training

# %%
def train_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0

    for batch in dataloader:
        optimizer.zero_grad()

        inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
        labels = batch['labels'].to(device)

        outputs = model(**inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate(model, dataloader, criterion, debug=False):
    model.eval()
    total_loss = 0.0
    predictions, true_labels = [], []
    class_losses = [0.0] * 4
    class_counts = [0] * 4

    with torch.no_grad():
        for batch_idx, batch in enumerate(dataloader):
            inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(device)

            # Forward pass
            logits = model(**inputs)
            loss = criterion(logits, labels)
            total_loss += loss.item()

            # Per-class loss calculation
            for class_idx in range(4):
                mask = (labels == class_idx)
                if mask.any():
                    class_loss = criterion(logits[mask], labels[mask]).item()
                    class_losses[class_idx] += class_loss * mask.sum().item()
                    class_counts[class_idx] += mask.sum().item()

                    if debug:
                        print(f"Batch {batch_idx} Class {class_idx} Loss: {class_loss:.4f} (n={mask.sum().item()})")

            # Store predictions
            _, preds = torch.max(logits, dim=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    avg_loss = total_loss / len(dataloader)
    class_avg_losses = [
        class_losses[i] / class_counts[i] if class_counts[i] > 0 else 0.0
        for i in range(4)
    ]

    return {
        'loss': avg_loss,
        'class_losses': class_avg_losses,
        'class_counts': class_counts,
        'accuracy': accuracy_score(true_labels, predictions),
        'f1': f1_score(true_labels, predictions, average='macro')
    }

# %%
best_val_loss = float('inf')  # Initialize with a very high value if tracking loss

# Training Loop
for epoch in range(10):
    model3.train()
    train_loss = train_epoch(model3, train_loader, optimizer, criterion)

    model3.eval()
    val_results = evaluate(model3, val_loader, criterion, debug=(epoch == 0))

    # Improved printing
    print(f"\nEpoch {epoch + 1}")
    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss: {val_results['loss']:.4f}")
    print(f"Val Accuracy: {val_results['accuracy']:.4f}")
    print(f"Val F1: {val_results['f1']:.4f}")

    # Class-wise performance
    class_names = ['conflict', 'negative', 'neutral', 'positive']
    print("\nClass-wise Val Loss:")
    for i, name in enumerate(class_names):
        if val_results['class_counts'][i] > 0:
            print(f"{name.upper():<9}: {val_results['class_losses'][i]:.4f} (n={val_results['class_counts'][i]})")
    print("-----")


    if val_results['loss'] < best_val_loss:
      best_val_loss = val_results['loss']
      torch.save({
          'epoch': epoch,
          'model_state_dict': model.state_dict(),
          'optimizer_state_dict': optimizer.state_dict(),
          'loss': train_loss,
          'val_loss': val_results['loss'],
          'val_accuracy': val_results['accuracy'],
      }, 'best_model3.pth')
      print(f"Saved new best model with val loss: {best_val_loss:.4f}")
# Out:
# Batch 0 Class 1 Loss: 0.4007 (n=4)
# Batch 0 Class 2 Loss: 0.6575 (n=6)
# Batch 0 Class 3 Loss: 0.4943 (n=6)
# Batch 1 Class 1 Loss: 0.4946 (n=4)
# Batch 1 Class 2 Loss: 0.7390 (n=3)
# Batch 1 Class 3 Loss: 0.8513 (n=9)
# Batch 2 Class 0 Loss: 1.5685 (n=1)
# Batch 2 Class 1 Loss: 1.3380 (n=3)
# Batch 2 Class 2 Loss: 0.7961 (n=1)
# Batch 2 Class 3 Loss: 0.6333 (n=11)
# Batch 3 Class 1 Loss: 0.6413 (n=5)
# Batch 3 Class 2 Loss: 0.5545 (n=3)
# Batch 3 Class 3 Loss: 0.2153 (n=8)
# Batch 4 Class 1 Loss: 0.8190 (n=6)
# Batch 4 Class 2 Loss: 1.5901 (n=1)
# Batch 4 Class 3 Loss: 0.2952 (n=9)
# Batch 5 Class 0 Loss: 3.2553 (n=1)
# Batch 5 Class 1 Loss: 1.6396 (n=3)
# Batch 5 Class 2 Loss: 0.7523 (n=3)
# Batch 5 Class 3 Loss: 1.1024 (n=9)
# Batch 6 Class 1 Loss: 0.5962 (n=4)
# Batch 6 Class 2 Loss: 0.8301 (n=5)
# Batch 6 Class 3 Loss: 0.6631 (n=7)
# Batch 7 Class 1 Loss: 0.9833 (n=7)
# Batch 7 Class 2 Loss: 0.8006 (n=2)
# Batch 7 Class 3 Loss: 0.9564 (n=7)
# Batch 8 Class 1 Loss: 0.5689 (n=3)
# Batch 8 Class 2 Loss: 1.2031 (n=4)
# Batch 8 Class 3 Loss: 0.5545 (n=9)
# Batch 9 Class 0 Loss: 2.2205 (n=1)
# Batch 9 Class 1 Loss: 0.5849 (n=6)
# Batch 9 Class 2 Loss: 0.7677 (n=3)
# Batch 9 Class 3 Loss: 0.7593 (n=6)
# Batch 10 Class 0 Loss: 2.3302 (n=1)
# Batch 10 Class 1 Loss: 0.5832 (n=6)
# Batch 10 Class 2 Loss: 1.1482 (n=3)
# Batch 10 Class 3 Loss: 1.2083 (n=6)
# Batch 11 Class 1 Loss: 0.6297 (n=3)
# Batch 11 Class 2 Loss: 1.1364 (n=6)
# Batch 11 Class 3 Loss: 0.5174 (n=7)
# Batch 12 Class 1 Loss: 0.3377 (n=3)
# Batch 12 Class 2 Loss: 0.9449 (n=5)
# Batch 12 Class 3 Loss: 0.7223 (n=8)
# Batch 13 Class 1 Loss: 1.1650 (n=2)
# Batch 13 Class 2 Loss: 1.2617 (n=4)
# Batch 13 Class 3 Loss: 0.5858 (n=10)
# Batch 14 Class 1 Loss: 0.9872 (n=6)
# Batch 14 Class 2 Loss: 1.1649 (n=1)
# Batch 14 Class 3 Loss: 0.5371 (n=9)
# Batch 15 Class 0 Loss: 1.6107 (n=1)
# Batch 15 Class 1 Loss: 0.6781 (n=2)
# Batch 15 Class 2 Loss: 0.6967 (n=4)
# Batch 15 Class 3 Loss: 0.6065 (n=9)
# Batch 16 Class 1 Loss: 0.3891 (n=2)
# Batch 16 Class 2 Loss: 0.5707 (n=4)
# Batch 16 Class 3 Loss: 0.8088 (n=10)
# Batch 17 Class 0 Loss: 2.0889 (n=1)
# Batch 17 Class 1 Loss: 1.1238 (n=4)
# Batch 17 Class 2 Loss: 0.9805 (n=5)
# Batch 17 Class 3 Loss: 0.3192 (n=6)
# Batch 18 Class 1 Loss: 0.6262 (n=4)
# Batch 18 Class 2 Loss: 1.1430 (n=5)
# Batch 18 Class 3 Loss: 0.2957 (n=7)
# Batch 19 Class 1 Loss: 0.4928 (n=4)
# Batch 19 Class 2 Loss: 0.9182 (n=2)
# Batch 19 Class 3 Loss: 0.2589 (n=10)
# Batch 20 Class 1 Loss: 1.3883 (n=3)
# Batch 20 Class 2 Loss: 0.6418 (n=1)
# Batch 20 Class 3 Loss: 0.3453 (n=12)
# Batch 21 Class 1 Loss: 0.6059 (n=10)
# Batch 21 Class 2 Loss: 0.5803 (n=1)
# Batch 21 Class 3 Loss: 0.4744 (n=5)
# Batch 22 Class 1 Loss: 1.0144 (n=5)
# Batch 22 Class 2 Loss: 1.2305 (n=3)
# Batch 22 Class 3 Loss: 0.4117 (n=8)
# Batch 23 Class 0 Loss: 2.3243 (n=1)
# Batch 23 Class 1 Loss: 0.4070 (n=6)
# Batch 23 Class 2 Loss: 0.5757 (n=3)
# Batch 23 Class 3 Loss: 0.3774 (n=6)
# Batch 24 Class 1 Loss: 1.4205 (n=7)
# Batch 24 Class 2 Loss: 0.9351 (n=2)
# Batch 24 Class 3 Loss: 1.0087 (n=7)
# Batch 25 Class 1 Loss: 0.4850 (n=8)
# Batch 25 Class 2 Loss: 0.5060 (n=1)
# Batch 25 Class 3 Loss: 0.7216 (n=7)
# Batch 26 Class 1 Loss: 0.5859 (n=3)
# Batch 26 Class 2 Loss: 1.0484 (n=5)
# Batch 26 Class 3 Loss: 1.0771 (n=8)
# Batch 27 Class 0 Loss: 2.2363 (n=1)
# Batch 27 Class 1 Loss: 0.7349 (n=5)
# Batch 27 Class 2 Loss: 0.8306 (n=3)
# Batch 27 Class 3 Loss: 0.5680 (n=7)
# Batch 28 Class 1 Loss: 0.4730 (n=3)
# Batch 28 Class 2 Loss: 1.1509 (n=5)
# Batch 28 Class 3 Loss: 0.5272 (n=8)
# Batch 29 Class 1 Loss: 1.3729 (n=3)
# Batch 29 Class 2 Loss: 0.9693 (n=8)
# Batch 29 Class 3 Loss: 0.7200 (n=5)
# Batch 30 Class 1 Loss: 0.7328 (n=2)
# Batch 30 Class 2 Loss: 1.6397 (n=1)
# Batch 30 Class 3 Loss: 0.3576 (n=13)
# Batch 31 Class 1 Loss: 0.3808 (n=2)
# Batch 31 Class 2 Loss: 2.5827 (n=1)
# Batch 31 Class 3 Loss: 0.6968 (n=13)
# Batch 32 Class 1 Loss: 0.3293 (n=1)
# Batch 32 Class 2 Loss: 0.6595 (n=4)
# Batch 32 Class 3 Loss: 0.9366 (n=11)
# Batch 33 Class 1 Loss: 0.9076 (n=5)
# Batch 33 Class 2 Loss: 0.6852 (n=2)
# Batch 33 Class 3 Loss: 0.4106 (n=9)
# Batch 34 Class 1 Loss: 1.3577 (n=5)
# Batch 34 Class 2 Loss: 0.8545 (n=5)
# Batch 34 Class 3 Loss: 0.5957 (n=6)
# Batch 35 Class 1 Loss: 0.7133 (n=5)
# Batch 35 Class 2 Loss: 0.5710 (n=3)
# Batch 35 Class 3 Loss: 0.9683 (n=8)
# Batch 36 Class 1 Loss: 0.2972 (n=1)
# Batch 36 Class 2 Loss: 1.2062 (n=4)
# Batch 36 Class 3 Loss: 0.5720 (n=11)
# Batch 37 Class 1 Loss: 0.7579 (n=7)
# Batch 37 Class 2 Loss: 0.7461 (n=1)
# Batch 37 Class 3 Loss: 0.6294 (n=8)
# Batch 38 Class 0 Loss: 2.0383 (n=1)
# Batch 38 Class 1 Loss: 0.6663 (n=3)
# Batch 38 Class 2 Loss: 1.1190 (n=4)
# Batch 38 Class 3 Loss: 0.5565 (n=8)
# Batch 39 Class 1 Loss: 0.6121 (n=6)
# Batch 39 Class 2 Loss: 1.3009 (n=1)
# Batch 39 Class 3 Loss: 0.5282 (n=9)
# Batch 40 Class 0 Loss: 1.9574 (n=1)
# Batch 40 Class 1 Loss: 1.4277 (n=5)
# Batch 40 Class 2 Loss: 0.5876 (n=2)
# Batch 40 Class 3 Loss: 0.5122 (n=8)
# Batch 41 Class 1 Loss: 0.8098 (n=4)
# Batch 41 Class 2 Loss: 1.1354 (n=3)
# Batch 41 Class 3 Loss: 0.5541 (n=9)
# Batch 42 Class 1 Loss: 1.1619 (n=5)
# Batch 42 Class 2 Loss: 1.6671 (n=4)
# Batch 42 Class 3 Loss: 0.2960 (n=7)
# Batch 43 Class 1 Loss: 0.4493 (n=3)
# Batch 43 Class 2 Loss: 1.2048 (n=1)
# Batch 43 Class 3 Loss: 0.9532 (n=12)
# Batch 44 Class 1 Loss: 0.7406 (n=8)
# Batch 44 Class 2 Loss: 0.7777 (n=3)
# Batch 44 Class 3 Loss: 0.5825 (n=5)
# Batch 45 Class 0 Loss: 2.0907 (n=2)
# Batch 45 Class 1 Loss: 0.4371 (n=5)
# Batch 45 Class 2 Loss: 1.7493 (n=3)
# Batch 45 Class 3 Loss: 0.3351 (n=6)
# Batch 46 Class 1 Loss: 0.5175 (n=4)
# Batch 46 Class 2 Loss: 0.9502 (n=5)
# Batch 46 Class 3 Loss: 0.6045 (n=7)
# Batch 47 Class 1 Loss: 1.3428 (n=2)
# Batch 47 Class 2 Loss: 1.4630 (n=1)
# Batch 47 Class 3 Loss: 1.0092 (n=13)
# Batch 48 Class 0 Loss: 2.4225 (n=1)
# Batch 48 Class 1 Loss: 0.8588 (n=7)
# Batch 48 Class 3 Loss: 0.8691 (n=8)
# Batch 49 Class 0 Loss: 3.4190 (n=1)
# Batch 49 Class 1 Loss: 0.4254 (n=5)
# Batch 49 Class 2 Loss: 1.4963 (n=2)
# Batch 49 Class 3 Loss: 0.4705 (n=8)
# Batch 50 Class 1 Loss: 0.7894 (n=4)
# Batch 50 Class 2 Loss: 1.2392 (n=2)
# Batch 50 Class 3 Loss: 0.6419 (n=10)
# Batch 51 Class 1 Loss: 0.7453 (n=5)
# Batch 51 Class 2 Loss: 1.0415 (n=6)
# Batch 51 Class 3 Loss: 0.3737 (n=5)
# Batch 52 Class 1 Loss: 1.9186 (n=3)
# Batch 52 Class 2 Loss: 0.6207 (n=4)
# Batch 52 Class 3 Loss: 0.2329 (n=9)
# Batch 53 Class 1 Loss: 0.4366 (n=2)
# Batch 53 Class 2 Loss: 1.0365 (n=3)
# Batch 53 Class 3 Loss: 0.8478 (n=11)
# Batch 54 Class 1 Loss: 0.6652 (n=5)
# Batch 54 Class 2 Loss: 0.5110 (n=2)
# Batch 54 Class 3 Loss: 0.5096 (n=9)
# Batch 55 Class 1 Loss: 1.8067 (n=5)
# Batch 55 Class 2 Loss: 0.5187 (n=3)
# Batch 55 Class 3 Loss: 0.7437 (n=8)
# Batch 56 Class 0 Loss: 1.9382 (n=1)
# Batch 56 Class 1 Loss: 1.0231 (n=2)
# Batch 56 Class 2 Loss: 0.7201 (n=1)
# Batch 56 Class 3 Loss: 0.6034 (n=8)
#
# Epoch 1
# Train Loss: 1.2560
# Val Loss: 0.9752
# Val Accuracy: 0.7269
# Val F1: 0.5135
#
# Class-wise Val Loss:
# CONFLICT : 2.2395 (n=15)
# NEGATIVE : 0.8106 (n=245)
# NEUTRAL  : 0.9638 (n=173)
# POSITIVE : 0.6212 (n=475)
# -----
# Saved new best model with val loss: 0.9752
#
# Epoch 2
# Train Loss: 0.9727
# Val Loss: 0.8434
# Val Accuracy: 0.6795
# Val F1: 0.5668
#
# Class-wise Val Loss:
# CONFLICT : 0.4815 (n=15)
# NEGATIVE : 0.8358 (n=245)
# NEUTRAL  : 1.0082 (n=173)
# POSITIVE : 0.8243 (n=475)
# -----
# Saved new best model with val loss: 0.8434
#
# Epoch 3
# Train Loss: 0.7939
# Val Loss: 0.8444
# Val Accuracy: 0.6949
# Val F1: 0.5717
#
# Class-wise Val Loss:
# CONFLICT : 0.2897 (n=15)
# NEGATIVE : 0.6274 (n=245)
# NEUTRAL  : 1.2735 (n=173)
# POSITIVE : 0.8722 (n=475)
# -----
#
# Epoch 4
# Train Loss: 0.6402
# Val Loss: 0.9843
# Val Accuracy: 0.7048
# Val F1: 0.5718
#
# Class-wise Val Loss:
# CONFLICT : 1.5783 (n=15)
# NEGATIVE : 0.9978 (n=245)
# NEUTRAL  : 1.0338 (n=173)
# POSITIVE : 0.6389 (n=475)
# -----
#
# Epoch 5
# Train Loss: 0.5361
# Val Loss: 1.0545
# Val Accuracy: 0.7093
# Val F1: 0.5789
#
# Class-wise Val Loss:
# CONFLICT : 1.7518 (n=15)
# NEGATIVE : 0.9491 (n=245)
# NEUTRAL  : 1.0352 (n=173)
# POSITIVE : 0.8766 (n=475)
# -----
#
# Epoch 6
# Train Loss: 0.4414
# Val Loss: 1.0213
# Val Accuracy: 0.7026
# Val F1: 0.5760
#
# Class-wise Val Loss:
# CONFLICT : 1.2123 (n=15)
# NEGATIVE : 0.8907 (n=245)
# NEUTRAL  : 1.2189 (n=173)
# POSITIVE : 0.8779 (n=475)
# -----
#
# Epoch 7
# Train Loss: 0.3679
# Val Loss: 1.1092
# Val Accuracy: 0.7412
# Val F1: 0.5878
#
# Class-wise Val Loss:
# CONFLICT : 1.8147 (n=15)
# NEGATIVE : 0.8114 (n=245)
# NEUTRAL  : 1.4929 (n=173)
# POSITIVE : 0.7348 (n=475)
# -----
#
# Epoch 8
# Train Loss: 0.3191
# Val Loss: 1.2635
# Val Accuracy: 0.7225
# Val F1: 0.5785
#
# Class-wise Val Loss:
# CONFLICT : 2.6988 (n=15)
# NEGATIVE : 1.1323 (n=245)
# NEUTRAL  : 1.2657 (n=173)
# POSITIVE : 0.7835 (n=475)
# -----
#
# Epoch 9
# Train Loss: 0.2872
# Val Loss: 1.3334
# Val Accuracy: 0.7148
# Val F1: 0.5805
#
# Class-wise Val Loss:
# CONFLICT : 2.0343 (n=15)
# NEGATIVE : 0.9829 (n=245)
# NEUTRAL  : 1.8165 (n=173)
# POSITIVE : 0.9082 (n=475)
# -----
#
# Epoch 10
# Train Loss: 0.2535
# Val Loss: 1.3604
# Val Accuracy: 0.7379
# Val F1: 0.6095
#
# Class-wise Val Loss:
# CONFLICT : 2.4546 (n=15)
# NEGATIVE : 1.1688 (n=245)
# NEUTRAL  : 1.7019 (n=173)
# POSITIVE : 0.6880 (n=475)
# -----

# %%
checkpoint = torch.load('best_model3.pth')
print(f"Model 3 Best validation loss: {checkpoint['val_loss']:.4f}")
print(f"Achieved at epoch: {checkpoint['epoch'] + 1}")

# Evaluate on the test set ONLY ONCE
model3.eval()
test_results = evaluate(model3, test_loader, criterion)
print(f"\nModel 3 Final Test Performance:")
print(f"Test Loss: {test_results['loss']:.4f}")
print(f"Test Accuracy: {test_results['accuracy']:.4f}")
print(f"Test F1: {test_results['f1']:.4f}")
# Out:
# Model 3 Best validation loss: 0.8434
# Achieved at epoch: 2
#
# Model 3 Final Test Performance:
# Test Loss: 1.5514
# Test Accuracy: 0.7313
# Test F1: 0.5861

# %%
torch.save(model3.state_dict(), 'model3.pt')

# %% [markdown]
# ## Model 2: some enhancements

# %%
# Model Architecture
class AspectSentimentClassifier(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = torch.nn.Dropout(0.5)

        # Enhanced classifier with intermediate layers
        self.classifier = torch.nn.Sequential(
        torch.nn.Linear(768 * 2, 256),
        torch.nn.GELU(),
        torch.nn.Dropout(0.5),
        torch.nn.Linear(256, 4)
    )

    def forward(self, sentence_input_ids, sentence_attention_mask, aspect_input_ids, aspect_attention_mask):
        # Get sentence embeddings
        sentence_outputs = self.bert(
            input_ids=sentence_input_ids,
            attention_mask=sentence_attention_mask
        )
        sentence_embedding = sentence_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Get aspect embeddings
        aspect_outputs = self.bert(
            input_ids=aspect_input_ids,
            attention_mask=aspect_attention_mask
        )
        aspect_embedding = aspect_outputs.last_hidden_state[:, 0, :]  # CLS token

        # Combine features
        combined = torch.cat([sentence_embedding, aspect_embedding], dim=1)
        combined = self.dropout(combined)
        logits = self.classifier(combined)

        return logits

# %%
# Training Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model4 = AspectSentimentClassifier().to(device)
optimizer = AdamW(model4.parameters(), lr=2e-5)

# %%
class_counts = torch.tensor([
    91,    # conflict (class 0)
    805,   # negative (class 1)
    633,   # neutral (class 2)
    2164   # positive (class 3)
])

# Calculate weights (inverse frequency)
weights = 1. / class_counts.float()

# Normalize to sum to num_classes (4)
weights = weights / weights.sum() * len(class_counts)

# Verify weight-class alignment
print({
    'conflict': weights[0].item(),  # Should be LARGEST (~3.75)
    'negative': weights[1].item(),   # ~1.23
    'neutral': weights[2].item(),    # ~1.57
    'positive': weights[3].item()    # Should be SMALLEST (~0.45)
})

# Initialize loss function
criterion = torch.nn.CrossEntropyLoss(weight=weights.to(device))
# Out:
# {'conflict': 3.0796351432800293, 'negative': 0.3481326401233673, 'neutral': 0.4427279531955719, 'positive': 0.12950406968593597}

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

# %%
# Training Loop
def train_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0

    for batch in dataloader:
        optimizer.zero_grad()

        inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
        labels = batch['labels'].to(device)

        outputs = model(**inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate(model, dataloader, criterion, debug=False):
    model.eval()
    total_loss = 0.0
    predictions, true_labels = [], []
    class_losses = [0.0] * 4
    class_counts = [0] * 4

    with torch.no_grad():
        for batch_idx, batch in enumerate(dataloader):
            inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(device)

            # Forward pass
            logits = model(**inputs)
            loss = criterion(logits, labels)
            total_loss += loss.item()

            # Per-class loss calculation
            for class_idx in range(4):
                mask = (labels == class_idx)
                if mask.any():
                    class_loss = criterion(logits[mask], labels[mask]).item()
                    class_losses[class_idx] += class_loss * mask.sum().item()
                    class_counts[class_idx] += mask.sum().item()

                    if debug:
                        print(f"Batch {batch_idx} Class {class_idx} Loss: {class_loss:.4f} (n={mask.sum().item()})")

            # Store predictions
            _, preds = torch.max(logits, dim=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    avg_loss = total_loss / len(dataloader)
    class_avg_losses = [
        class_losses[i] / class_counts[i] if class_counts[i] > 0 else 0.0
        for i in range(4)
    ]

    return {
        'loss': avg_loss,
        'class_losses': class_avg_losses,
        'class_counts': class_counts,
        'accuracy': accuracy_score(true_labels, predictions),
        'f1': f1_score(true_labels, predictions, average='macro')
    }

# %%
best_val_loss = float('inf')  # Initialize with a very high value if tracking loss

# Training Loop
for epoch in range(10):
    model4.train()
    train_loss = train_epoch(model4, train_loader, optimizer, criterion)

    model4.eval()
    val_results = evaluate(model4, val_loader, criterion, debug=(epoch == 0))

    # Improved printing
    print(f"\nEpoch {epoch + 1}")
    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss: {val_results['loss']:.4f}")
    print(f"Val Accuracy: {val_results['accuracy']:.4f}")
    print(f"Val F1: {val_results['f1']:.4f}")

    # Class-wise performance
    class_names = ['conflict', 'negative', 'neutral', 'positive']
    print("\nClass-wise Val Loss:")
    for i, name in enumerate(class_names):
        if val_results['class_counts'][i] > 0:
            print(f"{name.upper():<9}: {val_results['class_losses'][i]:.4f} (n={val_results['class_counts'][i]})")
    print("-----")

    if val_results['loss'] < best_val_loss:
      best_val_loss = val_results['loss']
      torch.save({
          'epoch': epoch,
          'model_state_dict': model.state_dict(),
          'optimizer_state_dict': optimizer.state_dict(),
          'loss': train_loss,
          'val_loss': val_results['loss'],
          'val_accuracy': val_results['accuracy'],
      }, 'best_model4.pth')
      print(f"Saved new best model with val loss: {best_val_loss:.4f}")
# Out:
# Batch 0 Class 1 Loss: 0.3849 (n=4)
# Batch 0 Class 2 Loss: 1.0249 (n=6)
# Batch 0 Class 3 Loss: 0.5856 (n=6)
# Batch 1 Class 1 Loss: 0.6525 (n=4)
# Batch 1 Class 2 Loss: 0.9147 (n=3)
# Batch 1 Class 3 Loss: 0.7815 (n=9)
# Batch 2 Class 0 Loss: 0.9841 (n=1)
# Batch 2 Class 1 Loss: 1.1073 (n=3)
# Batch 2 Class 2 Loss: 1.8111 (n=1)
# Batch 2 Class 3 Loss: 0.5824 (n=11)
# Batch 3 Class 1 Loss: 0.8340 (n=5)
# Batch 3 Class 2 Loss: 0.9669 (n=3)
# Batch 3 Class 3 Loss: 0.3203 (n=8)
# Batch 4 Class 1 Loss: 0.9238 (n=6)
# Batch 4 Class 2 Loss: 0.9084 (n=1)
# Batch 4 Class 3 Loss: 0.4597 (n=9)
# Batch 5 Class 0 Loss: 1.9898 (n=1)
# Batch 5 Class 1 Loss: 1.5321 (n=3)
# Batch 5 Class 2 Loss: 1.0775 (n=3)
# Batch 5 Class 3 Loss: 1.0942 (n=9)
# Batch 6 Class 1 Loss: 0.8515 (n=4)
# Batch 6 Class 2 Loss: 1.0293 (n=5)
# Batch 6 Class 3 Loss: 0.6266 (n=7)
# Batch 7 Class 1 Loss: 0.8192 (n=7)
# Batch 7 Class 2 Loss: 0.8901 (n=2)
# Batch 7 Class 3 Loss: 0.8097 (n=7)
# Batch 8 Class 1 Loss: 0.5659 (n=3)
# Batch 8 Class 2 Loss: 1.1941 (n=4)
# Batch 8 Class 3 Loss: 0.5593 (n=9)
# Batch 9 Class 0 Loss: 1.2495 (n=1)
# Batch 9 Class 1 Loss: 0.9731 (n=6)
# Batch 9 Class 2 Loss: 1.2989 (n=3)
# Batch 9 Class 3 Loss: 0.8743 (n=6)
# Batch 10 Class 0 Loss: 1.0257 (n=1)
# Batch 10 Class 1 Loss: 0.6681 (n=6)
# Batch 10 Class 2 Loss: 1.3733 (n=3)
# Batch 10 Class 3 Loss: 1.2136 (n=6)
# Batch 11 Class 1 Loss: 1.2703 (n=3)
# Batch 11 Class 2 Loss: 1.3025 (n=6)
# Batch 11 Class 3 Loss: 0.6427 (n=7)
# Batch 12 Class 1 Loss: 0.5157 (n=3)
# Batch 12 Class 2 Loss: 1.2419 (n=5)
# Batch 12 Class 3 Loss: 0.8705 (n=8)
# Batch 13 Class 1 Loss: 0.7826 (n=2)
# Batch 13 Class 2 Loss: 1.5956 (n=4)
# Batch 13 Class 3 Loss: 0.6406 (n=10)
# Batch 14 Class 1 Loss: 0.9521 (n=6)
# Batch 14 Class 2 Loss: 1.8016 (n=1)
# Batch 14 Class 3 Loss: 0.7448 (n=9)
# Batch 15 Class 0 Loss: 1.2121 (n=1)
# Batch 15 Class 1 Loss: 0.5191 (n=2)
# Batch 15 Class 2 Loss: 1.1791 (n=4)
# Batch 15 Class 3 Loss: 0.6061 (n=9)
# Batch 16 Class 1 Loss: 0.4786 (n=2)
# Batch 16 Class 2 Loss: 0.6926 (n=4)
# Batch 16 Class 3 Loss: 0.9252 (n=10)
# Batch 17 Class 0 Loss: 1.1472 (n=1)
# Batch 17 Class 1 Loss: 0.8405 (n=4)
# Batch 17 Class 2 Loss: 1.2000 (n=5)
# Batch 17 Class 3 Loss: 0.5027 (n=6)
# Batch 18 Class 1 Loss: 0.7481 (n=4)
# Batch 18 Class 2 Loss: 1.1888 (n=5)
# Batch 18 Class 3 Loss: 0.3604 (n=7)
# Batch 19 Class 1 Loss: 0.6631 (n=4)
# Batch 19 Class 2 Loss: 1.8426 (n=2)
# Batch 19 Class 3 Loss: 0.4560 (n=10)
# Batch 20 Class 1 Loss: 1.1622 (n=3)
# Batch 20 Class 2 Loss: 1.5434 (n=1)
# Batch 20 Class 3 Loss: 0.5419 (n=12)
# Batch 21 Class 1 Loss: 1.0182 (n=10)
# Batch 21 Class 2 Loss: 0.6718 (n=1)
# Batch 21 Class 3 Loss: 0.8008 (n=5)
# Batch 22 Class 1 Loss: 0.9898 (n=5)
# Batch 22 Class 2 Loss: 1.7272 (n=3)
# Batch 22 Class 3 Loss: 0.6139 (n=8)
# Batch 23 Class 0 Loss: 1.0145 (n=1)
# Batch 23 Class 1 Loss: 0.7061 (n=6)
# Batch 23 Class 2 Loss: 0.8155 (n=3)
# Batch 23 Class 3 Loss: 0.5833 (n=6)
# Batch 24 Class 1 Loss: 1.2903 (n=7)
# Batch 24 Class 2 Loss: 1.1603 (n=2)
# Batch 24 Class 3 Loss: 0.8155 (n=7)
# Batch 25 Class 1 Loss: 0.8288 (n=8)
# Batch 25 Class 2 Loss: 0.7966 (n=1)
# Batch 25 Class 3 Loss: 0.5933 (n=7)
# Batch 26 Class 1 Loss: 0.8187 (n=3)
# Batch 26 Class 2 Loss: 1.1317 (n=5)
# Batch 26 Class 3 Loss: 0.8436 (n=8)
# Batch 27 Class 0 Loss: 1.6668 (n=1)
# Batch 27 Class 1 Loss: 0.6915 (n=5)
# Batch 27 Class 2 Loss: 0.8809 (n=3)
# Batch 27 Class 3 Loss: 0.7400 (n=7)
# Batch 28 Class 1 Loss: 0.7674 (n=3)
# Batch 28 Class 2 Loss: 1.2600 (n=5)
# Batch 28 Class 3 Loss: 0.5410 (n=8)
# Batch 29 Class 1 Loss: 1.2780 (n=3)
# Batch 29 Class 2 Loss: 1.0256 (n=8)
# Batch 29 Class 3 Loss: 0.5884 (n=5)
# Batch 30 Class 1 Loss: 0.6954 (n=2)
# Batch 30 Class 2 Loss: 1.8064 (n=1)
# Batch 30 Class 3 Loss: 0.6263 (n=13)
# Batch 31 Class 1 Loss: 0.5874 (n=2)
# Batch 31 Class 2 Loss: 2.7193 (n=1)
# Batch 31 Class 3 Loss: 0.7648 (n=13)
# Batch 32 Class 1 Loss: 0.6881 (n=1)
# Batch 32 Class 2 Loss: 0.8675 (n=4)
# Batch 32 Class 3 Loss: 0.8954 (n=11)
# Batch 33 Class 1 Loss: 0.9359 (n=5)
# Batch 33 Class 2 Loss: 0.6735 (n=2)
# Batch 33 Class 3 Loss: 0.5490 (n=9)
# Batch 34 Class 1 Loss: 1.1498 (n=5)
# Batch 34 Class 2 Loss: 1.2841 (n=5)
# Batch 34 Class 3 Loss: 0.4648 (n=6)
# Batch 35 Class 1 Loss: 0.9475 (n=5)
# Batch 35 Class 2 Loss: 1.1849 (n=3)
# Batch 35 Class 3 Loss: 0.8720 (n=8)
# Batch 36 Class 1 Loss: 0.3669 (n=1)
# Batch 36 Class 2 Loss: 1.4796 (n=4)
# Batch 36 Class 3 Loss: 0.7465 (n=11)
# Batch 37 Class 1 Loss: 0.8051 (n=7)
# Batch 37 Class 2 Loss: 0.6040 (n=1)
# Batch 37 Class 3 Loss: 0.4959 (n=8)
# Batch 38 Class 0 Loss: 1.0835 (n=1)
# Batch 38 Class 1 Loss: 0.7566 (n=3)
# Batch 38 Class 2 Loss: 1.6116 (n=4)
# Batch 38 Class 3 Loss: 0.8010 (n=8)
# Batch 39 Class 1 Loss: 0.6598 (n=6)
# Batch 39 Class 2 Loss: 1.6036 (n=1)
# Batch 39 Class 3 Loss: 0.5169 (n=9)
# Batch 40 Class 0 Loss: 1.0206 (n=1)
# Batch 40 Class 1 Loss: 1.5052 (n=5)
# Batch 40 Class 2 Loss: 0.9334 (n=2)
# Batch 40 Class 3 Loss: 0.6152 (n=8)
# Batch 41 Class 1 Loss: 0.5526 (n=4)
# Batch 41 Class 2 Loss: 1.3523 (n=3)
# Batch 41 Class 3 Loss: 0.5209 (n=9)
# Batch 42 Class 1 Loss: 1.3313 (n=5)
# Batch 42 Class 2 Loss: 1.7599 (n=4)
# Batch 42 Class 3 Loss: 0.3665 (n=7)
# Batch 43 Class 1 Loss: 0.6821 (n=3)
# Batch 43 Class 2 Loss: 1.3066 (n=1)
# Batch 43 Class 3 Loss: 0.8761 (n=12)
# Batch 44 Class 1 Loss: 1.0901 (n=8)
# Batch 44 Class 2 Loss: 1.1408 (n=3)
# Batch 44 Class 3 Loss: 0.6447 (n=5)
# Batch 45 Class 0 Loss: 0.9564 (n=2)
# Batch 45 Class 1 Loss: 0.7269 (n=5)
# Batch 45 Class 2 Loss: 1.4930 (n=3)
# Batch 45 Class 3 Loss: 0.4279 (n=6)
# Batch 46 Class 1 Loss: 0.8191 (n=4)
# Batch 46 Class 2 Loss: 1.4475 (n=5)
# Batch 46 Class 3 Loss: 0.6958 (n=7)
# Batch 47 Class 1 Loss: 1.0450 (n=2)
# Batch 47 Class 2 Loss: 1.9403 (n=1)
# Batch 47 Class 3 Loss: 0.8879 (n=13)
# Batch 48 Class 0 Loss: 1.0489 (n=1)
# Batch 48 Class 1 Loss: 0.9082 (n=7)
# Batch 48 Class 3 Loss: 0.7842 (n=8)
# Batch 49 Class 0 Loss: 1.6941 (n=1)
# Batch 49 Class 1 Loss: 0.6281 (n=5)
# Batch 49 Class 2 Loss: 1.4339 (n=2)
# Batch 49 Class 3 Loss: 0.5278 (n=8)
# Batch 50 Class 1 Loss: 0.9563 (n=4)
# Batch 50 Class 2 Loss: 0.9240 (n=2)
# Batch 50 Class 3 Loss: 0.5077 (n=10)
# Batch 51 Class 1 Loss: 0.6950 (n=5)
# Batch 51 Class 2 Loss: 1.1903 (n=6)
# Batch 51 Class 3 Loss: 0.5032 (n=5)
# Batch 52 Class 1 Loss: 1.7568 (n=3)
# Batch 52 Class 2 Loss: 1.0666 (n=4)
# Batch 52 Class 3 Loss: 0.3872 (n=9)
# Batch 53 Class 1 Loss: 0.5021 (n=2)
# Batch 53 Class 2 Loss: 1.1721 (n=3)
# Batch 53 Class 3 Loss: 0.8334 (n=11)
# Batch 54 Class 1 Loss: 0.9673 (n=5)
# Batch 54 Class 2 Loss: 0.6025 (n=2)
# Batch 54 Class 3 Loss: 0.7305 (n=9)
# Batch 55 Class 1 Loss: 1.4548 (n=5)
# Batch 55 Class 2 Loss: 0.5496 (n=3)
# Batch 55 Class 3 Loss: 0.6039 (n=8)
# Batch 56 Class 0 Loss: 1.1865 (n=1)
# Batch 56 Class 1 Loss: 0.7654 (n=2)
# Batch 56 Class 2 Loss: 1.1985 (n=1)
# Batch 56 Class 3 Loss: 0.5898 (n=8)
#
# Epoch 1
# Train Loss: 1.2425
# Val Loss: 0.9667
# Val Accuracy: 0.7291
# Val F1: 0.5822
#
# Class-wise Val Loss:
# CONFLICT : 1.2157 (n=15)
# NEGATIVE : 0.8988 (n=245)
# NEUTRAL  : 1.1994 (n=173)
# POSITIVE : 0.6655 (n=475)
# -----
# Saved new best model with val loss: 0.9667
#
# Epoch 2
# Train Loss: 0.8929
# Val Loss: 0.8197
# Val Accuracy: 0.7247
# Val F1: 0.5737
#
# Class-wise Val Loss:
# CONFLICT : 1.5992 (n=15)
# NEGATIVE : 0.5842 (n=245)
# NEUTRAL  : 0.8337 (n=173)
# POSITIVE : 0.7232 (n=475)
# -----
# Saved new best model with val loss: 0.8197
#
# Epoch 3
# Train Loss: 0.7045
# Val Loss: 0.8168
# Val Accuracy: 0.7269
# Val F1: 0.5873
#
# Class-wise Val Loss:
# CONFLICT : 1.1845 (n=15)
# NEGATIVE : 0.8235 (n=245)
# NEUTRAL  : 0.9139 (n=173)
# POSITIVE : 0.5117 (n=475)
# -----
# Saved new best model with val loss: 0.8168
#
# Epoch 4
# Train Loss: 0.5386
# Val Loss: 0.8359
# Val Accuracy: 0.7225
# Val F1: 0.5901
#
# Class-wise Val Loss:
# CONFLICT : 1.2350 (n=15)
# NEGATIVE : 0.7353 (n=245)
# NEUTRAL  : 0.9953 (n=173)
# POSITIVE : 0.5839 (n=475)
# -----
#
# Epoch 5
# Train Loss: 0.4415
# Val Loss: 0.8951
# Val Accuracy: 0.6927
# Val F1: 0.5708
#
# Class-wise Val Loss:
# CONFLICT : 0.5208 (n=15)
# NEGATIVE : 1.1311 (n=245)
# NEUTRAL  : 0.9434 (n=173)
# POSITIVE : 0.6877 (n=475)
# -----
#
# Epoch 6
# Train Loss: 0.3653
# Val Loss: 0.9802
# Val Accuracy: 0.7048
# Val F1: 0.5707
#
# Class-wise Val Loss:
# CONFLICT : 0.6612 (n=15)
# NEGATIVE : 0.7562 (n=245)
# NEUTRAL  : 1.5571 (n=173)
# POSITIVE : 0.7483 (n=475)
# -----
#
# Epoch 7
# Train Loss: 0.3051
# Val Loss: 1.0936
# Val Accuracy: 0.7269
# Val F1: 0.5887
#
# Class-wise Val Loss:
# CONFLICT : 1.5446 (n=15)
# NEGATIVE : 0.8372 (n=245)
# NEUTRAL  : 1.6526 (n=173)
# POSITIVE : 0.5862 (n=475)
# -----
#
# Epoch 8
# Train Loss: 0.2545
# Val Loss: 1.1634
# Val Accuracy: 0.7324
# Val F1: 0.6089
#
# Class-wise Val Loss:
# CONFLICT : 2.2511 (n=15)
# NEGATIVE : 0.9479 (n=245)
# NEUTRAL  : 1.4192 (n=173)
# POSITIVE : 0.6771 (n=475)
# -----
#
# Epoch 9
# Train Loss: 0.2249
# Val Loss: 1.2310
# Val Accuracy: 0.7445
# Val F1: 0.6025
#
# Class-wise Val Loss:
# CONFLICT : 2.8271 (n=15)
# NEGATIVE : 1.0693 (n=245)
# NEUTRAL  : 1.4414 (n=173)
# POSITIVE : 0.5054 (n=475)
# -----
#
# Epoch 10
# Train Loss: 0.1892
# Val Loss: 1.3011
# Val Accuracy: 0.7401
# Val F1: 0.5898
#
# Class-wise Val Loss:
# CONFLICT : 2.8735 (n=15)
# NEGATIVE : 0.9291 (n=245)
# NEUTRAL  : 1.6984 (n=173)
# POSITIVE : 0.6403 (n=475)
# -----

# %%
checkpoint = torch.load('best_model4.pth')
print(f"Model 4 Best validation loss: {checkpoint['val_loss']:.4f}")
print(f"Achieved at epoch: {checkpoint['epoch'] + 1}")

# Evaluate on the test set ONLY ONCE
model4.eval()
test_results = evaluate(model4, test_loader, criterion)
print(f"\nModel 4 Final Test Performance:")
print(f"Test Loss: {test_results['loss']:.4f}")
print(f"Test Accuracy: {test_results['accuracy']:.4f}")
print(f"Test F1: {test_results['f1']:.4f}")
# Out:
# Model 4 Best validation loss: 0.8168
# Achieved at epoch: 3
#
# Model 4 Final Test Performance:
# Test Loss: 1.3695
# Test Accuracy: 0.7225
# Test F1: 0.5784

# %%
# saving the model as model 4
torch.save(model4.state_dict(), 'model4.pt')

# %% [markdown]
# # Using model

# %%
# Prepare inputs (example)
sentence = "The food was great but service was terrible"
aspect = "service"

# Tokenize SEPARATELY for sentence and aspect
sentence_enc = tokenizer(sentence, return_tensors='pt', padding=True, truncation=True)
aspect_enc = tokenizer(aspect, return_tensors='pt', padding=True, truncation=True)

model.eval()
with torch.no_grad():
    logits = model(
        sentence_input_ids=sentence_enc['input_ids'].to(device),
        sentence_attention_mask=sentence_enc['attention_mask'].to(device),
        aspect_input_ids=aspect_enc['input_ids'].to(device),
        aspect_attention_mask=aspect_enc['attention_mask'].to(device)
    )
    print(logits)
    probs = torch.softmax(logits, dim=1)
    pred_class = torch.argmax(probs).item()

# Map to label
id2label = {0: 'conflict', 1: 'negative', 2: 'neutral', 3: 'positive'}
print(f"Predicted: {id2label[pred_class]} (Confidence: {probs[0][pred_class]:.2%})")
# Out:
# tensor([[ 0.0322,  1.3697, -1.4105,  0.3239]], device='cuda:0')
# Predicted: negative (Confidence: 59.67%)
